# %% [markdown]
# ## Homework 2 - Part I
# ### Opal Issan
#
# #### Single Programmer Affidavit
# I the undersigned promise that the attached assignment is my own work. While I was free to discuss ideas with others, the work contained is my own. I recognize that should this not be the case, I will be subject to penalties as outlined in the course syllabus.

# %% [markdown]
# Q1: In class, we stated that the Manhattan distance is consistent for N-puzzles
# if one assumes that the cost of a move is 2 (swap one tile each way).
# Prove that the Manhattan distance is not consistent with a cost of 1.

# %% [markdown]
# ### TODO ###

# %% [markdown]
# Q2: An agent is navigating the following fictional landscape on planet Kepler
# 22-b that corresponds to the function:
#
# $ f(x, y) = 150 \sin(xy/10) - 2y -3x + xy + x^2 + y^2$.
#
# The agent is looking for the lowest point in the landscape (goal: find
# potential surface water)
#
# a) What is the gradient function?
#
#
# b) Given position (-.6, 7), what would the new position be after one update if the
# update step size is 0.01?
#
#
# c) Verify that this decreases the objective
# function by computing the objective function at the original and new
# locations

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
plt.rcParams['figure.figsize'] = [15, 8]

# %%
def fun(x, y):
    """ return the function output of f(x,y)= 150sin(𝑥𝑦/10)−2𝑦−3𝑥+𝑥𝑦+𝑥^2+𝑦^2"""
    return 150*np.sin(x*y/10) -2*y -3*x +x*y + x**2 + y**2

# %%
x = np.linspace(-10, 10, 100)
y = np.linspace(-10, 10, 100)
X, Y = np.meshgrid(x, y)
Z= fun(X,Y)

# %%
fig = plt.figure()
ax = plt.axes(projection='3d', azim=60, elev=70)
ax.contour3D(X, Y, Z, 200)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
# Out:
# Text(0.5, 0, 'z')

# %% [markdown]
# Answers Q2:
#
# a) $\nabla (f) = [\frac{\partial f}{\partial x}  \frac{\partial f}{\partial y}]^{T}$
#
# $\frac{\partial f}{\partial x} = 15x\cos(xy/10) -3 + y+2x$
#
# $\frac{\partial f}{\partial y} = 15y\cos(xy/10) -2 + x+2y$

# %%
def gradient(x, y):
    """ return the graidnet of the function above."""
    dfdx = 15*x*np.cos(x*y/10) - 3 + y + 2*x
    dfdy = 15*y*np.cos(x*y/10) - 2+ x + 2*y
    return np.array([dfdx, dfdy])

# %% [markdown]
# b)

# %%
 gradient(-0.6, 7)
# Out:
# array([ -5.41780046, 107.27433873])

# %% [markdown]
# $\nabla (f(-0.6, 7)) = [-5.41780046,  107.27433873]^{T}$

# %%
fun(-0.6, 7)
# Out:
# -28.20406795893554

# %%
xk = np.array([-0.6, 7])
alpha = 0.01
xk = xk + alpha*gradient(-0.6, 7)

# %%
print("The new position after one update is = ", xk)
# Out:
# The new position after one update is =  [-0.654178    8.07274339]

# %% [markdown]
# c)

# %%
print("f(x_{k})", fun(-0.6, 7))
print("f(x_{k+1})", fun(xk[0], xk[1]))
print("f(x_{k+1}) < f(x_{k})")
# Out:
# f(x_{k}) -28.20406795893554
# f(x_{k+1}) -29.450938310154143
# f(x_{k+1}) < f(x_{k})

# %% [markdown]
# # Q3 ## TODO ##

# %% [markdown]
# 4) Q: Consider the fairly simple problem of selecting 2 matching cards from a deck of
# cards with pictures on them. The pictures consist of moon, sun, and stars, and
# there are two instances of each card (6 cards in total). Legal moves are pick a
# card that has not been picked, and the goal state is matching the first card drawn.
# Sketch an and-or search tree for this problem. You do not need to draw the full
# tree, just enough to make it clear that you understand what the full tree would
# look like.

# %% [markdown]
# ![graph](hw2_p4_new.png)
